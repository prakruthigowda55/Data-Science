# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]

plt.plot(x,y) #(1,4),(2,5),(3,6)
plt.show()
plt.grid()

# %% [markdown]
# PYPLOT API

# %%
# univariate--> particularly which graph is ti use for the give data
# numarical

data = {
    "salary" : [25000, 30000, 37000, 28000, 39000, 48000, 55000, 52000, 35000, 26000, 27000, 31000, 33000, 29000, 40000, 36000, 34000, 45000, 47000, 50000]
}

df=pd.DataFrame(data)
df.head()
# Out:
#    salary
# 0   25000
# 1   30000
# 2   37000
# 3   28000
# 4   39000

# %%
df.shape
# Out:
# (20, 1)

# %%
# line plot

plt.plot(df["salary"],color="red",marker="*",linestyle=":",linewidth="2")
plt.grid()
plt.show()

# %%
# Histogram

plt.hist(df["salary"],bins=5,color="blue")
plt.show()

# %%
# boxplot

plt.boxplot(df["salary"])
plt.show()

# %%
df.loc[20]=[0]

# %%
plt.boxplot(df["salary"])
plt.show()  # outliers last dot

# %%
df.drop(index = 20, inplace = True)

# %%
df.shape
# Out:
# (20, 1)

# %%
# univeriate : categorical coloum

# %%
df["dept"] = ['HR', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'HR', 'Finance', 'IT', 'HR'] * 2

# %%
df.head()
# Out:
#    salary     dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HR
# 4   39000  Finance

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   salary  20 non-null     int64
#  1   dept    20 non-null     str
# dtypes: int64(1), str(1)
# memory usage: 452.0 bytes

# %%
# pie chart:

count=df["dept"].value_counts()
print(count)

plt.pie(count,labels=count.index,autopct="%1.2f",explode=[0,0.1,0.5])
plt.axis("equal")# make the pie chart circle
plt.show()
# Out:
# dept
# HR         8
# IT         6
# Finance    6
# Name: count, dtype: int64

# %%
# countplot

plt.bar(count.index,count,color=["green","red","blue"])
plt.show()

# %%
# Bivariate analysis-->two coloums
# two numerical colums 
# numerical -- numerical

# %%
df.head()
# Out:
#    salary     dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HR
# 4   39000  Finance

# %%
df["age"] = [22, 25, 29, 24, 30, 35, 40, 36, 28, 22, 23, 25, 26, 24, 31, 29, 27, 33, 35, 38]

# %%
df.head()
# Out:
#    salary     dept  Age  age
# 0   25000       HR   22   22
# 1   30000       IT   25   25
# 2   37000  Finance   29   29
# 3   28000       HR   24   24
# 4   39000  Finance   30   30

# %%
# scatter plot
plt.scatter(df["age"],df["salary"],color="yellow")
plt.show()

# %%
sort_age=df.sort_values("age")

# %%
# Line plot:

plt.plot(sort_age["age"], df["salary"], color = "red", marker = "*", linewidth = "2")
plt.grid()
plt.show()

# %%
# bar chart:
plt.bar(sort_age["age"], df["salary"], color = "green")
plt.show()

# %%
# bivariate: numerical--categorical

# %%
hr_sal=df[df["dept"]=="HR"]["salary"]
hr_sal
# Out:
# 0     25000
# 3     28000
# 6     55000
# 9     26000
# 10    27000
# 13    29000
# 16    34000
# 19    50000
# Name: salary, dtype: int64

# %%
it_sal = df[df["dept"] == "IT"]["salary"]
it_sal
# Out:
# 1     30000
# 5     48000
# 8     35000
# 11    31000
# 15    36000
# 18    47000
# Name: salary, dtype: int64

# %%
fin_sal = df[df["dept"] == "Finance"]["salary"]
fin_sal
# Out:
# 2     37000
# 4     39000
# 7     52000
# 12    33000
# 14    40000
# 17    45000
# Name: salary, dtype: int64

# %%
# Boxplot:

plt.boxplot(
    [hr_sal, it_sal, fin_sal],
    tick_labels=["Hr", "IT", "Finance"]
)

plt.show()

# %%
# pie chart:

salary_by_dept = df.groupby("dept")["salary"].sum()
salary_by_dept
# Out:
# dept
# Finance    246000
# HR         274000
# IT         227000
# Name: salary, dtype: int64

# %%
plt.pie(salary_by_dept, labels = salary_by_dept.index, autopct = "%1.2f", shadow = True, explode = [0.1, 0, 0.1])
plt.axis("equal")
plt.show()

# %%
# bar plot

hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(fin_sal)/len(fin_sal)

# %%
plt.bar(["HR", "IT", "Finance"], [hr_mean, it_mean, fin_mean], color = ["green", "black", "red"])
plt.grid()
plt.show()

# %%
# Multivariate Analysis: 3 numerical columns

# %%
df.head()
# Out:
#    salary     dept  Age  age
# 0   25000       HR   22   22
# 1   30000       IT   25   25
# 2   37000  Finance   29   29
# 3   28000       HR   24   24
# 4   39000  Finance   30   30

# %%
df["experience"] =  [1, 2, 4, 1.5, 5, 8, 12, 10, 4, 1, 1.2, 2, 3, 1.8, 5.5, 4.5, 3.2, 7, 8, 10]

# %%
# Bubble PLot:

plt.scatter(df["age"], df["salary"], s = df["experience"]*50, color = "skyblue", edgecolors= "black")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
# 2 numerical and 1 categorical column:

# %%
plt.scatter(df["age"], df["salary"], c = df["dept"].map({"HR": "yellow", "IT":"blue", "Finance": "orange"}))
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary vs Dept")
plt.legend()
plt.show()
# Out:
# C:\Users\prakr\AppData\Local\Temp\ipykernel_23500\134675505.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
color = {"HR": "yellow", "IT":"blue", "Finance": "orange"}

for dept, color in color.items():
    df_dept = df[df["dept"] == dept]
    plt.scatter(df_dept["age"], df_dept["salary"], c = color, label = dept)

plt.legend()

# %% [markdown]
# Object Oriented API

# %%
fig, axs = plt.subplots(1,3, figsize = (15,5))

# Line plot

axs[0].plot(sort_age["age"], df["salary"], color = "red", marker = "*", linewidth = "2", markersize = 2)
axs[0].grid()
axs[0].set_title("Line Plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")

# histogram:

axs[1].hist(df["salary"], bins = 5, color = "skyblue")
axs[1].set_title("Histogram")
axs[1].set_xlabel("Salary")
axs[1].set_ylabel("Frequency")


# Boxplot:

axs[2].boxplot(df["salary"])
axs[2].set_title("Boxplot")
axs[2].set_xlabel("Salary")

plt.savefig("multipleplots.png")
plt.show()

# %%
data2 = {
    'Year': [2020, 2021, 2022, 2023],
    'Sales': [100, 150, 200, 250],
    'Profit': [20, 30, 40, 50],
    'Expenses': [80, 120, 160, 200]
}

# %%
df2 = pd.DataFrame(data2)

# %%
plt.plot(df2["Year"], df2["Sales"], label = "Sales")
plt.plot(df2["Year"], df2["Profit"], label = "Profit")
plt.plot(df2["Year"], df2["Expenses"], label = "Expenses")

plt.title("Financial Analysis")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# # 3-D Plot:

# %%
df.head()
# Out:
#    salary     dept  Age  age  experience
# 0   25000       HR   22   22         1.0
# 1   30000       IT   25   25         2.0
# 2   37000  Finance   29   29         4.0
# 3   28000       HR   24   24         1.5
# 4   39000  Finance   30   30         5.0

# %%
ax = plt.axes(projection = "3d")

ax.scatter(df["age"], df["salary"], df["experience"])
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")
plt.show()
